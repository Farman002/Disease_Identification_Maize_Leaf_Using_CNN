# %%
import tensorflow as tf
import splitfolders
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = tf.keras.utils.image_dataset_from_directory('Dataset',
                                                  batch_size=32,
                                                  image_size=(256, 256),
                                                  shuffle=True,
                                                  )
# Out:
# Found 7316 files belonging to 4 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Common Rust', 'Gray Leaf Spot', 'Healthy', 'Northern Leaf Blight']

# %%
plt.figure(figsize=(10, 10))
class_counts = {class_name: 0 for class_name in class_names} 
display_limit = 1  
for img_batch, label_batch in dataset.take(5): 
    for i in range(len(img_batch)):
        class_name = class_names[label_batch[i]]
        if class_counts[class_name] < display_limit:
            ax = plt.subplot(3, 3, sum(class_counts.values()) + 1)
            plt.imshow(img_batch[i].numpy().astype("uint8"))
            plt.title(class_name)
            plt.axis("off")
            class_counts[class_name] += 1
        if sum(class_counts.values()) >= len(class_names):
            break
    if sum(class_counts.values()) >= len(class_names):
        break
plt.show()

# %%
dir1 = 'Dataset'

# %%
dir2 = 'Dataset2'
os.listdir(dir2)
# Out:
# []

# %%
splitfolders.ratio(dir1, 
                  output=dir2,
                  seed=27,
                  ratio=(0.8, 0.1, 0.1),
                  group_prefix=None)

# %%
train_path = dir2+'\\train\\'
test_path = dir2+'\\test\\'
validation_path = dir2+'\\val\\'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=10, 
                               width_shift_range=0.10, 
                               height_shift_range=0.10, 
                               rescale=1.0/255, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest' 
                              )

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                                target_size=(256, 256),
                                                color_mode='rgb',
                                                batch_size=32,
                                                class_mode='sparse'
                                               )
# Out:
# Found 5851 images belonging to 4 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=(256, 256),
                                               color_mode='rgb',
                                               batch_size=32,
                                               class_mode='sparse')
# Out:
# Found 736 images belonging to 4 classes.

# %%
validation_image_gen = image_gen.flow_from_directory(validation_path,
                                                     target_size=(256, 256),
                                                     color_mode='rgb',
                                                     batch_size=32,
                                                     class_mode='sparse')
# Out:
# Found 729 images belonging to 4 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(256, 256, 3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))    
   
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))    
   
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))    
    
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))    

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
          
model.add(Flatten())

model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(4))
model.add(Activation('softmax'))
# Out:
# C:\Users\farma\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 32)       │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 2, 2, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 4)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 157,156 (613.89 KB)
#  Trainable params: 157,156 (613.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=["accuracy"])

# %%
hist = model.fit(train_image_gen,
                 epochs=50,
                 validation_data=validation_image_gen,
                 batch_size=32,
                 verbose=1
                )
# Out:
# Epoch 1/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4626 - loss: 1.0438
# C:\Users\farma\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 447s 2s/step - accuracy: 0.4631 - loss: 1.0428 - val_accuracy: 0.6022 - val_loss: 0.7023
# Epoch 2/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 322s 2s/step - accuracy: 0.6940 - loss: 0.6301 - val_accuracy: 0.9040 - val_loss: 0.2714
# Epoch 3/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 324s 2s/step - accuracy: 0.9010 - loss: 0.2374 - val_accuracy: 0.8985 - val_loss: 0.2852
# Epoch 4/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 441s 2s/step - accuracy: 0.9304 - loss: 0.1841 - val_accuracy: 0.9053 - val_loss: 0.2405
# Epoch 5/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.9155 - loss: 0.2434 - val_accuracy: 0.9465 - val_loss: 0.1427
# Epoch 6/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 301s 2s/step - accuracy: 0.9442 - loss: 0.1524 - val_accuracy: 0.9410 - val_loss: 0.1444
# Epoch 7/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 298s 2s/step - accuracy: 0.9508 - loss: 0.1445 - val_accuracy: 0.9506 - val_loss: 0.1278
# Epoch 8/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 295s 2s/step - accuracy: 0.9445 - loss: 0.1333 - val_accuracy: 0.9328 - val_loss: 0.1686
# Epoch 9/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 1745s 10s/step - accuracy: 0.9477 - loss: 0.1271 - val_accuracy: 0.9383 - val_loss: 0.1649
# Epoch 10/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 326s 2s/step - accuracy: 0.9566 - loss: 0.1232 - val_accuracy: 0.9328 - val_loss: 0.1974
# Epoch 11/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 323s 2s/step - accuracy: 0.9472 - loss: 0.1429 - val_accuracy: 0.9630 - val_loss: 0.1116
# Epoch 12/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 373s 2s/step - accuracy: 0.9520 - loss: 0.1158 - val_accuracy: 0.9588 - val_loss: 0.1108
# Epoch 13/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 319s 2s/step - accuracy: 0.9574 - loss: 0.1167 - val_accuracy: 0.9602 - val_loss: 0.0862
# Epoch 14/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 325s 2s/step - accuracy: 0.9567 - loss: 0.1136 - val_accuracy: 0.9657 - val_loss: 0.0860
# Epoch 15/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 322s 2s/step - accuracy: 0.9641 - loss: 0.1039 - val_accuracy: 0.9602 - val_loss: 0.0918
# Epoch 16/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 760s 4s/step - accuracy: 0.9676 - loss: 0.0958 - val_accuracy: 0.9602 - val_loss: 0.0961
# Epoch 17/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9600 - loss: 0.1153 - val_accuracy: 0.9684 - val_loss: 0.0820
# Epoch 18/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.9660 - loss: 0.0896 - val_accuracy: 0.9712 - val_loss: 0.0818
# Epoch 19/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9624 - loss: 0.1020 - val_accuracy: 0.9767 - val_loss: 0.0691
# Epoch 20/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9648 - loss: 0.0849 - val_accuracy: 0.9643 - val_loss: 0.0905
# Epoch 21/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9566 - loss: 0.1043 - val_accuracy: 0.9739 - val_loss: 0.0787
# Epoch 22/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9711 - loss: 0.0817 - val_accuracy: 0.9753 - val_loss: 0.0666
# Epoch 23/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9652 - loss: 0.0849 - val_accuracy: 0.9822 - val_loss: 0.0626
# Epoch 24/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9646 - loss: 0.0907 - val_accuracy: 0.9822 - val_loss: 0.0584
# Epoch 25/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9718 - loss: 0.0767 - val_accuracy: 0.9794 - val_loss: 0.0579
# Epoch 26/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9704 - loss: 0.0788 - val_accuracy: 0.9849 - val_loss: 0.0544
# Epoch 27/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9748 - loss: 0.0737 - val_accuracy: 0.9726 - val_loss: 0.0712
# Epoch 28/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9663 - loss: 0.0908 - val_accuracy: 0.9643 - val_loss: 0.0911
# Epoch 29/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.9724 - loss: 0.0744 - val_accuracy: 0.9684 - val_loss: 0.0772
# Epoch 30/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9707 - loss: 0.0784 - val_accuracy: 0.9684 - val_loss: 0.0970
# Epoch 31/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 190s 1s/step - accuracy: 0.9762 - loss: 0.0702 - val_accuracy: 0.9808 - val_loss: 0.0503
# Epoch 32/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.9751 - loss: 0.0740 - val_accuracy: 0.9808 - val_loss: 0.0653
# Epoch 33/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.9725 - loss: 0.0761 - val_accuracy: 0.9726 - val_loss: 0.0649
# Epoch 34/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.9731 - loss: 0.0767 - val_accuracy: 0.9726 - val_loss: 0.0745
# Epoch 35/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 193s 1s/step - accuracy: 0.9755 - loss: 0.0738 - val_accuracy: 0.9835 - val_loss: 0.0459
# Epoch 36/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9748 - loss: 0.0749 - val_accuracy: 0.9671 - val_loss: 0.0838
# Epoch 37/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.9788 - loss: 0.0640 - val_accuracy: 0.9835 - val_loss: 0.0611
# Epoch 38/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.9717 - loss: 0.0737 - val_accuracy: 0.9726 - val_loss: 0.0779
# Epoch 39/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.9804 - loss: 0.0563 - val_accuracy: 0.9835 - val_loss: 0.0480
# Epoch 40/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.9761 - loss: 0.0647 - val_accuracy: 0.9835 - val_loss: 0.0496
# Epoch 41/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 196s 1s/step - accuracy: 0.9796 - loss: 0.0555 - val_accuracy: 0.9753 - val_loss: 0.0587
# Epoch 42/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.9814 - loss: 0.0530 - val_accuracy: 0.9753 - val_loss: 0.0615
# Epoch 43/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 191s 1s/step - accuracy: 0.9776 - loss: 0.0611 - val_accuracy: 0.9739 - val_loss: 0.0703
# Epoch 44/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 297s 2s/step - accuracy: 0.9744 - loss: 0.0645 - val_accuracy: 0.9588 - val_loss: 0.0957
# Epoch 45/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 325s 2s/step - accuracy: 0.9736 - loss: 0.0709 - val_accuracy: 0.9863 - val_loss: 0.0471
# Epoch 46/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 324s 2s/step - accuracy: 0.9820 - loss: 0.0488 - val_accuracy: 0.9808 - val_loss: 0.0475
# Epoch 47/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 321s 2s/step - accuracy: 0.9772 - loss: 0.0534 - val_accuracy: 0.9877 - val_loss: 0.0430
# Epoch 48/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 323s 2s/step - accuracy: 0.9846 - loss: 0.0464 - val_accuracy: 0.9822 - val_loss: 0.0491
# Epoch 49/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 324s 2s/step - accuracy: 0.9843 - loss: 0.0444 - val_accuracy: 0.9520 - val_loss: 0.1423
# Epoch 50/50
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 323s 2s/step - accuracy: 0.9813 - loss: 0.0524 - val_accuracy: 0.9794 - val_loss: 0.0495

# %%
hist.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
plt.figure(figsize=(9, 5))
plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'], color='teal', label='Train_loss')
plt.plot(hist.history['val_loss'], color='orange', label='Val_loss')
plt.title('Training and Validation Loss')
plt.ylabel('loss')  
plt.xlabel('epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist.history['accuracy'], color='teal', label='Train_Accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='Val_Accuracy')
plt.title('Training and Validation Accuracy')
plt.ylabel('accuracy')  
plt.xlabel('epoch')
plt.legend()

plt.show()

# %%
test_loss, test_acc=model.evaluate(test_image_gen)
print('Test Accuracy:', test_acc*100)
print('Test Loss:', test_loss*100)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 17s 736ms/step - accuracy: 0.9876 - loss: 0.0330
# Test Accuracy: 98.2336938381195
# Test Loss: 5.033348500728607

# %%
class_indices = {v: k for k, v in train_image_gen.class_indices.items()}
class_indices
# Out:
# {0: 'Common Rust',
#  1: 'Gray Leaf Spot',
#  2: 'Healthy',
#  3: 'Northern Leaf Blight'}

# %%
import json
json.dump(class_indices, open('class_indices.json', 'w'))

# %%
for image_batch, label_batch in test_image_gen:
    img_1 = image_batch[0]
    label_1 = int(label_batch[0])
    plt.imshow(img_1)
    print("actual label:",class_names[label_1])
    
    batch_pred = model.predict(image_batch)
    print("predicted label:",class_names[np.argmax(batch_pred[0])])
    
    break
# Out:
# actual label: Gray Leaf Spot
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# predicted label: Gray Leaf Spot

# %%
from tensorflow.keras.models import load_model
model.save('maize-leaf-disease-model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
